# %% [markdown]
# #AutoEncoders

# %% [markdown]
# ##Downloading the dataset

# %% [markdown]
# ###ML-100K

# %%
# !wget "http://files.grouplens.org/datasets/movielens/ml-100k.zip"
# !unzip ml-100k.zip
# !ls
# Out:
# --2020-06-20 03:30:11--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip’
#
# ml-100k.zip         100%[===================>]   4.70M  12.5MB/s    in 0.4s
#
# 2020-06-20 03:30:12 (12.5 MB/s) - ‘ml-100k.zip’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#    creating: ml-100k/
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test
# ml-100k  ml-100k.zip  sample_data

# %% [markdown]
# ###ML-1M

# %%
# !wget "http://files.grouplens.org/datasets/movielens/ml-1m.zip"
# !unzip ml-1m.zip
# !ls
# Out:
# --2020-06-20 03:30:29--  http://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917549 (5.6M) [application/zip]
# Saving to: ‘ml-1m.zip’
#
# ml-1m.zip           100%[===================>]   5.64M  14.9MB/s    in 0.4s
#
# 2020-06-20 03:30:29 (14.9 MB/s) - ‘ml-1m.zip’ saved [5917549/5917549]
#
# Archive:  ml-1m.zip
#    creating: ml-1m/
#   inflating: ml-1m/movies.dat
#   inflating: ml-1m/ratings.dat
#   inflating: ml-1m/README
#   inflating: ml-1m/users.dat
# ml-100k  ml-100k.zip  ml-1m  ml-1m.zip	sample_data

# %% [markdown]
# ##Importing the libraries

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %% [markdown]
# ## Importing the dataset

# %%
# We won't be using this dataset.
movies = pd.read_csv('ml-1m/movies.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')
users = pd.read_csv('ml-1m/users.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')
ratings = pd.read_csv('ml-1m/ratings.dat', sep = '::', header = None, engine = 'python', encoding = 'latin-1')

# %% [markdown]
# ## Preparing the training set and the test set

# %%
training_set = pd.read_csv('ml-100k/u1.base', delimiter = '\t')
training_set = np.array(training_set, dtype = 'int')
test_set = pd.read_csv('ml-100k/u1.test', delimiter = '\t')
test_set = np.array(test_set, dtype = 'int')

# %% [markdown]
# ## Getting the number of users and movies

# %%
nb_users = int(max(max(training_set[:, 0], ), max(test_set[:, 0])))
nb_movies = int(max(max(training_set[:, 1], ), max(test_set[:, 1])))

# %% [markdown]
# ## Converting the data into an array with users in lines and movies in columns

# %%
def convert(data):
  new_data = []
  for id_users in range(1, nb_users + 1):
    id_movies = data[:, 1] [data[:, 0] == id_users]
    id_ratings = data[:, 2] [data[:, 0] == id_users]
    ratings = np.zeros(nb_movies)
    ratings[id_movies - 1] = id_ratings
    new_data.append(list(ratings))
  return new_data
training_set = convert(training_set)
test_set = convert(test_set)

# %% [markdown]
# ## Converting the data into Torch tensors

# %%
training_set = torch.FloatTensor(training_set)
test_set = torch.FloatTensor(test_set)

# %% [markdown]
# ## Creating the architecture of the Neural Network

# %%
class SAE(nn.Module):

  def __init__(self, ):
    super(SAE, self).__init__()
    self.fc1 = nn.Linear(nb_movies, 20)
    self.fc2 = nn.Linear(20, 10)
    self.fc3 = nn.Linear(10, 20)
    self.fc4 = nn.Linear(20, nb_movies)
    self.activation = nn.Sigmoid()

  def forward(self, X):
    X = self.activation(self.fc1(X))
    X = self.activation(self.fc2(X))
    X = self.activation(self.fc3(X))
    X = self.fc4(X)
    return X

sae = SAE()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(sae.parameters(), lr=0.01, weight_decay=0.5)

# %% [markdown]
# ## Training the SAE

# %%
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
  train_loss = 0
  s = 0.
  for id_user in range(nb_users):
    input = Variable(training_set[id_user]).unsqueeze(0)
    target = input.clone()
    if torch.sum(target.data > 0) > 0:
      output = sae(input)
      target.require_grad = False
      output[target == 0] = 0
      loss = criterion(output, target)
      mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
      loss.backward()
      train_loss += np.sqrt(loss.data*mean_corrector)
      s += 1.
      optimizer.step()
  print('epoch: '+str(epoch)+' loss: '+ str(train_loss/s))
# Out:
# epoch: 1 loss: tensor(1.0174)
# epoch: 2 loss: tensor(1.0165)
# epoch: 3 loss: tensor(1.0168)
# epoch: 4 loss: tensor(1.0164)
# epoch: 5 loss: tensor(1.0163)
# epoch: 6 loss: tensor(1.0160)
# epoch: 7 loss: tensor(1.0162)
# epoch: 8 loss: tensor(1.0160)
# epoch: 9 loss: tensor(1.0159)
# epoch: 10 loss: tensor(1.0156)
# epoch: 11 loss: tensor(1.0156)
# epoch: 12 loss: tensor(1.0153)
# epoch: 13 loss: tensor(1.0153)
# epoch: 14 loss: tensor(1.0134)
# epoch: 15 loss: tensor(1.0115)
# epoch: 16 loss: tensor(1.0102)
# epoch: 17 loss: tensor(1.0078)
# epoch: 18 loss: tensor(1.0073)
# epoch: 19 loss: tensor(1.0038)
# epoch: 20 loss: tensor(1.0033)
# epoch: 21 loss: tensor(0.9999)
# epoch: 22 loss: tensor(0.9976)
# epoch: 23 loss: tensor(0.9962)
# epoch: 24 loss: tensor(0.9950)
# epoch: 25 loss: tensor(0.9936)
# epoch: 26 loss: tensor(0.9902)
# epoch: 27 loss: tensor(0.9869)
# epoch: 28 loss: tensor(0.9866)
# epoch: 29 loss: tensor(0.9853)
# epoch: 30 loss: tensor(0.9845)
# epoch: 31 loss: tensor(0.9818)
# epoch: 32 loss: tensor(0.9811)
# epoch: 33 loss: tensor(0.9766)
# epoch: 34 loss: tensor(0.9803)
# epoch: 35 loss: tensor(0.9760)
# epoch: 36 loss: tensor(0.9723)
# epoch: 37 loss: tensor(0.9705)
# epoch: 38 loss: tensor(0.9718)
# epoch: 39 loss: tensor(0.9701)
# epoch: 40 loss: tensor(0.9681)
# epoch: 41 loss: tensor(0.9659)
# epoch: 42 loss: tensor(0.9631)
# epoch: 43 loss: tensor(0.9621)
# epoch: 44 loss: tensor(0.9603)
# epoch: 45 loss: tensor(0.9582)
# epoch: 46 loss: tensor(0.9588)
# epoch: 47 loss: tensor(0.9613)
# epoch: 48 loss: tensor(0.9585)
# epoch: 49 loss: tensor(0.9603)
# epoch: 50 loss: tensor(0.9637)
# epoch: 51 loss: tensor(0.9717)
# epoch: 52 loss: tensor(0.9786)
# epoch: 53 loss: tensor(0.9748)
# epoch: 54 loss: tensor(0.9767)
# epoch: 55 loss: tensor(0.9725)
# epoch: 56 loss: tensor(0.9711)
# epoch: 57 loss: tensor(0.9654)
# epoch: 58 loss: tensor(0.9609)
# epoch: 59 loss: tensor(0.9687)
# epoch: 60 loss: tensor(0.9706)
# epoch: 61 loss: tensor(0.9661)
# epoch: 62 loss: tensor(0.9642)
# epoch: 63 loss: tensor(0.9610)
# epoch: 64 loss: tensor(0.9624)
# epoch: 65 loss: tensor(0.9593)
# epoch: 66 loss: tensor(0.9554)
# epoch: 67 loss: tensor(0.9533)
# epoch: 68 loss: tensor(0.9516)
# epoch: 69 loss: tensor(0.9495)
# epoch: 70 loss: tensor(0.9516)
# epoch: 71 loss: tensor(0.9488)
# epoch: 72 loss: tensor(0.9489)
# epoch: 73 loss: tensor(0.9488)
# epoch: 74 loss: tensor(0.9470)
# epoch: 75 loss: tensor(0.9472)
# epoch: 76 loss: tensor(0.9457)
# epoch: 77 loss: tensor(0.9423)
# epoch: 78 loss: tensor(0.9446)
# epoch: 79 loss: tensor(0.9437)
# epoch: 80 loss: tensor(0.9422)
# epoch: 81 loss: tensor(0.9423)
# epoch: 82 loss: tensor(0.9406)
# epoch: 83 loss: tensor(0.9398)
# epoch: 84 loss: tensor(0.9405)
# epoch: 85 loss: tensor(0.9396)
# epoch: 86 loss: tensor(0.9400)
# epoch: 87 loss: tensor(0.9374)
# epoch: 88 loss: tensor(0.9380)
# epoch: 89 loss: tensor(0.9371)
# epoch: 90 loss: tensor(0.9381)
# epoch: 91 loss: tensor(0.9380)
# epoch: 92 loss: tensor(0.9411)
# epoch: 93 loss: tensor(0.9452)
# epoch: 94 loss: tensor(0.9417)
# epoch: 95 loss: tensor(0.9415)
# epoch: 96 loss: tensor(0.9409)
# epoch: 97 loss: tensor(0.9398)
# epoch: 98 loss: tensor(0.9391)
# epoch: 99 loss: tensor(0.9377)
# epoch: 100 loss: tensor(0.9369)
# epoch: 101 loss: tensor(0.9364)
# epoch: 102 loss: tensor(0.9367)
# epoch: 103 loss: tensor(0.9358)
# epoch: 104 loss: tensor(0.9362)
# epoch: 105 loss: tensor(0.9347)
# epoch: 106 loss: tensor(0.9354)
# epoch: 107 loss: tensor(0.9332)
# epoch: 108 loss: tensor(0.9346)
# epoch: 109 loss: tensor(0.9329)
# epoch: 110 loss: tensor(0.9335)
# epoch: 111 loss: tensor(0.9321)
# epoch: 112 loss: tensor(0.9327)
# epoch: 113 loss: tensor(0.9308)
# epoch: 114 loss: tensor(0.9313)
# epoch: 115 loss: tensor(0.9295)
# epoch: 116 loss: tensor(0.9319)
# epoch: 117 loss: tensor(0.9294)
# epoch: 118 loss: tensor(0.9298)
# epoch: 119 loss: tensor(0.9284)
# epoch: 120 loss: tensor(0.9292)
# epoch: 121 loss: tensor(0.9277)
# epoch: 122 loss: tensor(0.9298)
# epoch: 123 loss: tensor(0.9264)
# epoch: 124 loss: tensor(0.9271)
# epoch: 125 loss: tensor(0.9274)
# epoch: 126 loss: tensor(0.9286)
# epoch: 127 loss: tensor(0.9270)
# epoch: 128 loss: tensor(0.9275)
# epoch: 129 loss: tensor(0.9254)
# epoch: 130 loss: tensor(0.9270)
# epoch: 131 loss: tensor(0.9254)
# epoch: 132 loss: tensor(0.9260)
# epoch: 133 loss: tensor(0.9242)
# epoch: 134 loss: tensor(0.9262)
# epoch: 135 loss: tensor(0.9241)
# epoch: 136 loss: tensor(0.9253)
# epoch: 137 loss: tensor(0.9239)
# epoch: 138 loss: tensor(0.9239)
# epoch: 139 loss: tensor(0.9234)
# epoch: 140 loss: tensor(0.9237)
# epoch: 141 loss: tensor(0.9223)
# epoch: 142 loss: tensor(0.9234)
# epoch: 143 loss: tensor(0.9212)
# epoch: 144 loss: tensor(0.9219)
# epoch: 145 loss: tensor(0.9221)
# epoch: 146 loss: tensor(0.9222)
# epoch: 147 loss: tensor(0.9209)
# epoch: 148 loss: tensor(0.9215)
# epoch: 149 loss: tensor(0.9203)
# epoch: 150 loss: tensor(0.9214)
# epoch: 151 loss: tensor(0.9200)
# epoch: 152 loss: tensor(0.9211)
# epoch: 153 loss: tensor(0.9201)
# epoch: 154 loss: tensor(0.9214)
# epoch: 155 loss: tensor(0.9198)
# epoch: 156 loss: tensor(0.9242)
# epoch: 157 loss: tensor(0.9194)
# epoch: 158 loss: tensor(0.9212)
# epoch: 159 loss: tensor(0.9191)
# epoch: 160 loss: tensor(0.9208)
# epoch: 161 loss: tensor(0.9187)
# epoch: 162 loss: tensor(0.9197)
# epoch: 163 loss: tensor(0.9188)
# epoch: 164 loss: tensor(0.9199)
# epoch: 165 loss: tensor(0.9184)
# epoch: 166 loss: tensor(0.9196)
# epoch: 167 loss: tensor(0.9181)
# epoch: 168 loss: tensor(0.9194)
# epoch: 169 loss: tensor(0.9179)
# epoch: 170 loss: tensor(0.9191)
# epoch: 171 loss: tensor(0.9174)
# epoch: 172 loss: tensor(0.9181)
# epoch: 173 loss: tensor(0.9172)
# epoch: 174 loss: tensor(0.9184)
# epoch: 175 loss: tensor(0.9169)
# epoch: 176 loss: tensor(0.9177)
# epoch: 177 loss: tensor(0.9168)
# epoch: 178 loss: tensor(0.9176)
# epoch: 179 loss: tensor(0.9164)
# epoch: 180 loss: tensor(0.9175)
# epoch: 181 loss: tensor(0.9164)
# epoch: 182 loss: tensor(0.9170)
# epoch: 183 loss: tensor(0.9159)
# epoch: 184 loss: tensor(0.9162)
# epoch: 185 loss: tensor(0.9155)
# epoch: 186 loss: tensor(0.9161)
# epoch: 187 loss: tensor(0.9146)
# epoch: 188 loss: tensor(0.9157)
# epoch: 189 loss: tensor(0.9148)
# epoch: 190 loss: tensor(0.9159)
# epoch: 191 loss: tensor(0.9145)
# epoch: 192 loss: tensor(0.9154)
# epoch: 193 loss: tensor(0.9150)
# epoch: 194 loss: tensor(0.9154)
# epoch: 195 loss: tensor(0.9146)
# epoch: 196 loss: tensor(0.9153)
# epoch: 197 loss: tensor(0.9147)
# epoch: 198 loss: tensor(0.9146)
# epoch: 199 loss: tensor(0.9134)
# epoch: 200 loss: tensor(0.9137)

# %% [markdown]
# ## Testing the SAE

# %%
test_loss = 0
s = 0.
for id_user in range(nb_users):
  input = Variable(training_set[id_user]).unsqueeze(0)
  target = Variable(training_set[id_user]).unsqueeze(0)
  if torch.sum(target.data > 0) > 0:
    output = sae(input)
    target.require_grad = False
    output[target == 0] = 0
    loss = criterion(output, target)
    mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
    test_loss += np.sqrt(loss.data*mean_corrector)
    s += 1.
print('test loss: '+ str(test_loss/s))
# Out:
# test loss: tensor(0.9240)
